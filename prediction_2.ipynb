# %%
import streamlit as st
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('/Users/um/Desktop/Wild Code School/Protojam/dataOk.csv')

# %%
df.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df_france = df[(df['Country']== 'France') & (df['Season']== 'Summer')]

# %%
""" data_france_encoded = pd.get_dummies(data_france, columns = ['Games', 'City', 'Sport', 'Event', 'Gender'], drop_first = True)
data_france_encoded['Medal'] = data_france_encoded['Medal'].map({'Gold': 3, 'Silver': 2, 'Bronze': 1, 'non-medalist':0}) """
""" 
prendre l'age moyen H et F
decisiontreeclassifier
grouper par event par année et par genre moyenne de l'age
essayer un modele pour les medailles d'or

"""
# Out:
# " \nprendre l'age moyen H et F\ndecisiontreeclassifier\ngrouper par event par année et par genre moyenne de l'age\nessayer un modele pour les medailles d'or\n\n"

# %%
df_france
# Out:
#                                       Name  Age Country  NOC        Games  \
# 98      Jamale (Djamel-) Aarrass (Ahrass-)   30  France  FRA  2012 Summer
# 145                          Patrick Abada   22  France  FRA  1976 Summer
# 149                             Ren Abadie   21  France  FRA  1956 Summer
# 150                             Ren Abadie   21  France  FRA  1956 Summer
# 173                              Luc Abalo   23  France  FRA  2008 Summer
# ...                                    ...  ...     ...  ...          ...
# 285890                        YUAN Jia Nan   36  France  FRA   2020Summer
# 285928                   ZAADI DEUNA Grace   28  France  FRA   2020Summer
# 285943                        ZAHI Carolle   27  France  FRA   2020Summer
# 286018                   ZEZE Meba Mickael   27  France  FRA   2020Summer
# 286019                           ZEZE Ryan   23  France  FRA   2020Summer
#
#         Year  Season       City         Sport  \
# ...

# %%
df_france.drop(columns = ['Games'], inplace = True)
# Out:
# /var/folders/39/cywg6p994nx3r3m3g0y5d1s00000gn/T/ipykernel_1302/1709192771.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
medals = {'non-medalist':0,
          'Gold':1,
          'Silver':2,
          'Bronze':3}

df['Medal_num'] = df['Medal'].map(medals)
df
# Out:
#                             Name  Age         Country  NOC        Games  Year  \
# 0                      A Dijiang   24           China  CHN  1992 Summer  1992
# 1                       A Lamusi   23           China  CHN  2012 Summer  2012
# 2            Gunnar Nielsen Aaby   24         Denmark  DEN  1920 Summer  1920
# 3           Edgar Lindenau Aabye   34  Denmark/Sweden  DEN  1900 Summer  1900
# 4       Christine Jacoba Aaftink   21     Netherlands  NED  1988 Winter  1988
# ...                          ...  ...             ...  ...          ...   ...
# 286157         ZWOLINSKA Klaudia   22          Poland  POL   2020Summer  2020
# 286158              ZYKOVA Yulia   25          Russia  ROC   2020Summer  2020
# 286159         ZYUZINA Ekaterina   24          Russia  ROC   2020Summer  2020
# 286160           ZYZANSKA Sylwia   24          Poland  POL   2020Summer  2020
# 286161           ZYZANSKA Sylwia   24          Poland  POL   2020Summer  2020
#
# ...

# %%
df.rename(columns = {'City':'Hote_City'})
# Out:
#                             Name  Age         Country  NOC        Games  Year  \
# 0                      A Dijiang   24           China  CHN  1992 Summer  1992
# 1                       A Lamusi   23           China  CHN  2012 Summer  2012
# 2            Gunnar Nielsen Aaby   24         Denmark  DEN  1920 Summer  1920
# 3           Edgar Lindenau Aabye   34  Denmark/Sweden  DEN  1900 Summer  1900
# 4       Christine Jacoba Aaftink   21     Netherlands  NED  1988 Winter  1988
# ...                          ...  ...             ...  ...          ...   ...
# 286157         ZWOLINSKA Klaudia   22          Poland  POL   2020Summer  2020
# 286158              ZYKOVA Yulia   25          Russia  ROC   2020Summer  2020
# 286159         ZYUZINA Ekaterina   24          Russia  ROC   2020Summer  2020
# 286160           ZYZANSKA Sylwia   24          Poland  POL   2020Summer  2020
# 286161           ZYZANSKA Sylwia   24          Poland  POL   2020Summer  2020
#
# ...
